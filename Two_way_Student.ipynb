# %%
from google.colab import drive
drive.mount('/content/gdrive',force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd
df = pd.read_csv('/content/gdrive/MyDrive/研究所課程/統計分析程式/資料集/StudentsPerformance.csv')

# %%
df = df.drop('race/ethnicity',axis=1)
df = df.drop('lunch',axis=1)
df = df.drop('gender',axis=1)

# %%
df['Total'] = (df['math score']+df['reading score']+df['writing score'])/3
df
# Out:
#     parental level of education test preparation course  math score  \
# 0             bachelor's degree                    none          72
# 1                  some college               completed          69
# 2               master's degree                    none          90
# 3            associate's degree                    none          47
# 4                  some college                    none          76
# ..                          ...                     ...         ...
# 995             master's degree               completed          88
# 996                 high school                    none          62
# 997                 high school               completed          59
# 998                some college               completed          68
# 999                some college                    none          77
#
#      reading score  writing score      Total
# 0               72             74  72.666667
# 1               90             88  82.333333
# 2               95             93  92.666667
# 3               57             44  49.333333
# 4               78             75  76.333333
# ..             ...            ...        ...
# 995             99             95  94.000000
# 996             55             55  57.333333
# 997             71             65  65.000000
# 998             78             77  74.333333
# 999             86             86  83.000000
#
# [1000 rows x 6 columns]

# %%
for i in range(len(df['Total'])):
  df['Total'][i] = round(df['Total'][i],2)
# Out:
# <ipython-input-5-87948f0056a6>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Total'][i] = round(df['Total'][i],2)

# %%
df = df.drop('math score',axis=1)
df = df.drop('reading score',axis=1)
df = df.drop('writing score',axis=1)

# %%
df_no = df[df['test preparation course']=="none"]
df_co = df[df['test preparation course']=="completed"]

# %%
df_shs = df_no[df_no['parental level of education']=="some high school"]
df_hs = df_no[df_no['parental level of education']=="high school"]
df_ad = df_no[df_no['parental level of education']=="associate's degree"]
df_sc = df_no[df_no['parental level of education']=="some college"]
df_bd = df_no[df_no['parental level of education']=="bachelor's degree"]
df_md = df_no[df_no['parental level of education']=="master's degree"]

# %%
df_shs = df_shs.sample(n=20,random_state=25,axis=0)
df_hs = df_hs.sample(n=20,random_state=25,axis=0)
df_ad = df_ad.sample(n=20,random_state=25,axis=0)
df_sc = df_sc.sample(n=20,random_state=25,axis=0)
df_bd = df_bd.sample(n=20,random_state=25,axis=0)
df_md = df_md.sample(n=20,random_state=25,axis=0)

# %%
df_mix = df_md.append(df_shs)
df_mix = df_mix.append(df_ad)
df_mix = df_mix.append(df_bd)
df_mix = df_mix.append(df_hs)
df_mix = df_mix.append(df_sc)
# Out:
# <ipython-input-10-430ba5d010b9>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mix = df_md.append(df_shs)
# <ipython-input-10-430ba5d010b9>:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mix = df_mix.append(df_ad)
# <ipython-input-10-430ba5d010b9>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mix = df_mix.append(df_bd)
# <ipython-input-10-430ba5d010b9>:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mix = df_mix.append(df_hs)
# <ipython-input-10-430ba5d010b9>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mix = df_mix.append(df_sc)

# %%
df_mix = df_mix.reset_index(drop=True)
df_mix
# Out:
#     parental level of education test preparation course  Total
# 0               master's degree                    none  54.33
# 1               master's degree                    none  63.33
# 2               master's degree                    none  95.67
# 3               master's degree                    none  51.67
# 4               master's degree                    none  78.00
# ..                          ...                     ...    ...
# 115                some college                    none  63.67
# 116                some college                    none  34.67
# 117                some college                    none  69.33
# 118                some college                    none  68.33
# 119                some college                    none  66.67
#
# [120 rows x 3 columns]

# %%
df_shs1 = df_co[df_co['parental level of education']=="some high school"]
df_hs1 = df_co[df_co['parental level of education']=="high school"]
df_ad1 = df_co[df_co['parental level of education']=="associate's degree"]
df_sc1 = df_co[df_co['parental level of education']=="some college"]
df_bd1 = df_co[df_co['parental level of education']=="bachelor's degree"]
df_md1 = df_co[df_co['parental level of education']=="master's degree"]

# %%
df_md1.shape
# Out:
# (20, 3)

# %%
df_shs1 = df_shs1.sample(n=20,random_state=25,axis=0)
df_hs1 = df_hs1.sample(n=20,random_state=25,axis=0)
df_ad1 = df_ad1.sample(n=20,random_state=25,axis=0)
df_sc1 = df_sc1.sample(n=20,random_state=25,axis=0)
df_bd1 = df_bd1.sample(n=20,random_state=25,axis=0)
df_md1 = df_md1.sample(n=20,random_state=25,axis=0)

# %%
df_mix1 = df_md1.append(df_shs1)
df_mix1 = df_mix1.append(df_ad1)
df_mix1 = df_mix1.append(df_bd1)
df_mix1 = df_mix1.append(df_hs1)
df_mix1 = df_mix1.append(df_sc1)
# Out:
# <ipython-input-15-f13b70dac52c>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mix1 = df_md1.append(df_shs1)
# <ipython-input-15-f13b70dac52c>:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mix1 = df_mix1.append(df_ad1)
# <ipython-input-15-f13b70dac52c>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mix1 = df_mix1.append(df_bd1)
# <ipython-input-15-f13b70dac52c>:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mix1 = df_mix1.append(df_hs1)
# <ipython-input-15-f13b70dac52c>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mix1 = df_mix1.append(df_sc1)

# %%
df_mix1 = df_mix1.reset_index(drop=True)
df_mix1
# Out:
#     parental level of education test preparation course  Total
# 0               master's degree               completed  87.67
# 1               master's degree               completed  89.33
# 2               master's degree               completed  86.33
# 3               master's degree               completed  57.33
# 4               master's degree               completed  75.67
# ..                          ...                     ...    ...
# 115                some college               completed  60.33
# 116                some college               completed  78.67
# 117                some college               completed  59.00
# 118                some college               completed  60.00
# 119                some college               completed  74.33
#
# [120 rows x 3 columns]

# %%
mix_CN = df_mix1.append(df_mix)
mix_CN
# Out:
# <ipython-input-17-9e201038b6f5>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   mix_CN = df_mix1.append(df_mix)
#     parental level of education test preparation course  Total
# 0               master's degree               completed  87.67
# 1               master's degree               completed  89.33
# 2               master's degree               completed  86.33
# 3               master's degree               completed  57.33
# 4               master's degree               completed  75.67
# ..                          ...                     ...    ...
# 115                some college                    none  63.67
# 116                some college                    none  34.67
# 117                some college                    none  69.33
# 118                some college                    none  68.33
# 119                some college                    none  66.67
#
# [240 rows x 3 columns]

# %%
import seaborn as sns

# %%
ax = sns.boxplot( data = mix_CN,x = "parental level of education", y = "Total", hue="test preparation course", palette = "Set3")

# %%
CH_CO = df_mix1.iloc[:,2:3]
CH_NO = df_mix.iloc[:,2:3]

# %%
CH_COM = CH_CO.to_numpy().flatten()
CH_NON = CH_NO.to_numpy().flatten()

# %%
import scipy.stats as stats

# %%
a = mix_CN[mix_CN['parental level of education']=="some high school"]
b = mix_CN[mix_CN['parental level of education']=="high school"]
c = mix_CN[mix_CN['parental level of education']=="associate's degree"]
d = mix_CN[mix_CN['parental level of education']=="some college"]
e = mix_CN[mix_CN['parental level of education']=="bachelor's degree"]
f = mix_CN[mix_CN['parental level of education']=="master's degree"]

# %%
aa = a.iloc[:,2:3]
bb = b.iloc[:,2:3]
cc = c.iloc[:,2:3]
dd = d.iloc[:,2:3]
ee = e.iloc[:,2:3]
ff = f.iloc[:,2:3]

# %%
aaa = aa.to_numpy().flatten()
bbb = bb.to_numpy().flatten()
ccc = cc.to_numpy().flatten()
ddd = dd.to_numpy().flatten()
eee = ee.to_numpy().flatten()
fff = ff.to_numpy().flatten()

# %% [markdown]
# 常態分配 P值>0.05常態

# %%
stats.shapiro(aaa)
# Out:
# ShapiroResult(statistic=0.986712634563446, pvalue=0.9123114943504333)

# %%
stats.shapiro(bbb)
# Out:
# ShapiroResult(statistic=0.9725956320762634, pvalue=0.433193564414978)

# %%
stats.shapiro(ccc)
# Out:
# ShapiroResult(statistic=0.9512718319892883, pvalue=0.08387507498264313)

# %%
stats.shapiro(ddd)
# Out:
# ShapiroResult(statistic=0.9397786259651184, pvalue=0.03399107605218887)

# %%
stats.shapiro(eee)
# Out:
# ShapiroResult(statistic=0.9793736934661865, pvalue=0.6662920713424683)

# %%
stats.shapiro(fff)
# Out:
# ShapiroResult(statistic=0.9708362817764282, pvalue=0.3823961913585663)

# %% [markdown]
# 檢查資料是否為相同變異數 P>0.05 相同變異數表示樣本來自相同母體

# %%
stats.levene(aaa,bbb,ccc,ddd,eee,fff)
# Out:
# LeveneResult(statistic=1.257117299204416, pvalue=0.2833580370906399)

# %% [markdown]
# ANOVA P值大於0.05 有影響

# %%
import statsmodels.api as sm

# %%
from statsmodels.formula.api import ols

# %%
df1 = mix_CN['Total'].to_numpy()
df2 = mix_CN['parental level of education'].to_numpy()
df3 = mix_CN['test preparation course'].to_numpy()

# %%
N_df = pd.DataFrame({'Total':df1,'Parent':df2,'TRY':df3})

# %%
mod = ols('Total ~ Parent*TRY', data = N_df).fit()
sm.stats.anova_lm(mod, typ = 2)
# Out:
#                   sum_sq     df          F    PR(>F)
# Parent       4842.747743    5.0   4.916373  0.000271
# TRY          2686.838002    1.0  13.638434  0.000277
# Parent:TRY    438.986113    5.0   0.445660  0.816197
# Residual    44917.112140  228.0        NaN       NaN

# %%
df_com = df_mix1.drop('test preparation course',axis=1)
df_non = df_mix.drop('test preparation course',axis=1)
